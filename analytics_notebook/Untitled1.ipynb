# %%
import pandas as pd

# %%
from google.cloud import bigquery
import google
from google.oauth2.service_account import Credentials

# %%
qr = "SELECT * FROM `ga-streaming-386407.analytics_373787125.events_intraday_20230512` LIMIT 1000"

# %%
creds = Credentials.from_service_account_file(
    '/Users/astrobalaji/Documents/stacknexus/tmdc_poc/gitrepo/retail_accelerator/Retail_Accelerator/dataos_yamls/depot/.secrets/ga-streaming-386407-201603edbd61.json')

# %%
from pandas.io import gbq

# %%
df = gbq.read_gbq(qr, project_id = "ga-streaming-386407", credentials = creds)

# %%
df
# Out:
#     event_date   event_timestamp       event_name  \
# 0     20230512  1683882931150844    session_start
# 1     20230512  1683882931150844  user_engagement
# 2     20230512  1683882941297288        page_view
# 3     20230512  1683882946301764    product_click
# 4     20230512  1683883712158108    product_click
# ..         ...               ...              ...
# 328   20230512  1683876177499061        page_view
# 329   20230512  1683876225933810  user_engagement
# 330   20230512  1683876232039629        page_view
# 331   20230512  1683878226569681    session_start
# 332   20230512  1683878226569681        page_view
#
#                                           event_params  \
# 0    [{'key': 'ignore_referrer', 'value': {'string_...
# 1    [{'key': 'page_location', 'value': {'string_va...
# 2    [{'key': 'ga_session_number', 'value': {'strin...
# 3    [{'key': 'session_engaged', 'value': {'string_...
# 4    [{'key': 'engagement_time_msec', 'value': {'st...
# ...
